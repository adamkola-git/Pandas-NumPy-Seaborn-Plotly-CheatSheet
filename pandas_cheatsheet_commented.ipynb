# %% [markdown]
# # 🐼 Pandas & Matplotlib Cheat Sheet (z komentarzami)

# %% [markdown]
# # 📦 Pandas Cheat Sheet (Series & DataFrame)
#
# ## ✅ Import
#
# ```python
# import pandas as pd      # Import biblioteki pandas
# import numpy as np       # Import biblioteki numpy
# ```
#
# ## 📚 Tworzenie danych
#
# ```python
# s = pd.Series([1, 2, 3], name="example")    # Tworzy Series z nazwą
# df = pd.DataFrame({                         # Tworzy DataFrame ze słownika
#     'A': [1, 2, 3],
#     'B': ['x', 'y', 'z']
# })
# ```
#
# ## 🧭 Eksploracja
#
# ```python
# df.head()          # Pierwsze 5 wierszy
# df.tail()          # Ostatnie 5 wierszy
# df.shape           # Liczba wierszy i kolumn (krotka)
# df.info()          # Informacje o kolumnach i typach danych
# df.describe()      # Statystyki dla kolumn liczbowych
# df.columns         # Lista nazw kolumn
# df.index           # Indeksy wierszy
# df.dtypes          # Typy danych kolumn
# ```
#
# ## 🔍 Selekcja danych
#
# ```python
# df['A']                # Zwraca kolumnę A jako Series
# df[['A', 'B']]         # Zwraca wybrane kolumny jako DataFrame
# df.iloc[0]             # Wiersz na pozycji 0 (wg indeksu numerycznego)
# df.loc[0]              # Wiersz o indeksie 0 (wg etykiety)
# df.iloc[0, 1]          # Wartość z 0. wiersza i 1. kolumny
# df.loc[0, 'A']         # Wartość z 0. wiersza i kolumny A
# ```
#
# ## 🧹 Filtrowanie
#
# ```python
# df[df['A'] > 1]                                 # Wiersze gdzie A > 1
# df[(df['A'] > 1) & (df['B'] == 'y')]            # Wiersze gdzie A > 1 i B == 'y'
# ```
#
# ## ✍️ Modyfikacja
#
# ```python
# df['C'] = df['A'] * 2                           # Nowa kolumna C jako A * 2
# df['B'] = df['B'].str.upper()                   # Zamiana tekstu w kolumnie B na wielkie litery
# df.drop('C', axis=1)                            # Usunięcie kolumny C
# df.drop(0, axis=0)                              # Usunięcie wiersza o indeksie 0
# df.rename(columns={'A': 'Alpha'})               # Zmiana nazwy kolumny A na Alpha
# ```
#
# ## 🔁 Funkcje
#
# ```python
# df.apply(np.sqrt)                              # Zastosowanie pierwiastka do każdego elementu
# df['A'].apply(lambda x: x**2)                  # Zastosowanie lambda do kolumny A
# ```
#
# ## 📊 Grupowanie
#
# ```python
# df.groupby('B').mean()                         # Średnia wartości w grupach B
# df.groupby('B')['A'].sum()                     # Suma A w grupach B
# ```
#
# ## 🧽 Czyszczenie
#
# ```python
# df.isnull()                                    # Sprawdza brakujące wartości
# df.dropna()                                    # Usuwa wiersze z brakującymi wartościami
# df.fillna(0)                                   # Zastępuje NaN zerami
# df.duplicated()                                # Sprawdza duplikaty wierszy
# df.drop_duplicates()                           # Usuwa duplikaty wierszy
# ```
#
# ## 🔀 Sortowanie
#
# ```python
# df.sort_values('A')                            # Sortuje po kolumnie A rosnąco
# df.sort_values(['A', 'B'])                     # Sortuje po A, potem B
# ```
#
# ## 📤 Wczytywanie / zapisywanie
#
# ```python
# pd.read_csv('plik.csv')                        # Wczytuje plik CSV do DataFrame
# df.to_csv('plik.csv', index=False)             # Zapisuje DataFrame do CSV bez indeksu
# ```
#
# ## 🧪 Indeksy
#
# ```python
# df.set_index('A')                              # Ustawia kolumnę A jako indeks
# df.reset_index()                               # Resetuje indeks do domyślnego
# ```
#
# ## 🔎 Szybkie analizy
#
# ```python
# df['A'].value_counts()                         # Liczba wystąpień unikalnych wartości
# df['A'].unique()                               # Lista unikalnych wartości
# df['A'].nunique()                              # Liczba unikalnych wartości
# ```

# %% [markdown]
# # 📈 Pandas / Matplotlib Plotting Cheat Sheet
#
# ## ✅ Import
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# ```
#
# ## 🐼 Wbudowane wykresy w Pandas
#
# ```python
# df['A'].plot()                         	# liniowy
# df.plot(kind='bar')                   	# słupkowy
# df.plot(kind='hist')                  	# histogram
# df.plot(kind='box')                   	# boxplot
# df.plot(kind='scatter', x='A', y='B') 	# scatter
# df.plot(kind='pie', y='A')            	# wykres kołowy
# ```
#
# ## ⚙️ Opcje formatowania
#
# ```python
# df.plot(title='Wykres', figsize=(8, 4), grid=True)
# ```
#
# ## 🎨 Matplotlib — kontrola totalna
#
# ```python
# plt.plot(df['A'])
# plt.scatter(df['A'], df['B'])
# plt.bar(df['A'], df['B'])
# plt.hist(df['A'], bins=10)
# plt.boxplot(df['A'])
# plt.title("Tytuł")
# plt.xlabel("Oś X")
# plt.ylabel("Oś Y")
# plt.grid(True)
# plt.show()
# ```
